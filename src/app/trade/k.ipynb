# %%
from tvDatafeed import TvDatafeed,Interval

# %%
tv=TvDatafeed()
# Out:
# you are using nologin method, data you access may be limited

# %%
nifty_index_data=tv.get_hist(symbol='NIFTY1!',exchange='NSE',interval=Interval.in_5_minute,n_bars=800)

# %%
nifty_index_data
# Out:
#                           symbol      open      high       low     close  \
# datetime
# 2025-04-09 13:25:00  NSE:NIFTY1!  22484.00  22500.00  22484.00  22490.00
# 2025-04-09 13:30:00  NSE:NIFTY1!  22490.25  22499.85  22476.10  22477.00
# 2025-04-09 13:35:00  NSE:NIFTY1!  22477.00  22477.05  22464.25  22466.25
# 2025-04-09 13:40:00  NSE:NIFTY1!  22467.50  22475.00  22465.00  22471.00
# 2025-04-09 13:45:00  NSE:NIFTY1!  22473.20  22481.95  22468.00  22477.55
# ...                          ...       ...       ...       ...       ...
# 2025-04-11 15:05:00  NSE:NIFTY1!  22920.95  22933.90  22903.95  22909.80
# 2025-04-11 15:10:00  NSE:NIFTY1!  22912.65  22923.90  22907.80  22917.65
# 2025-04-11 15:15:00  NSE:NIFTY1!  22917.65  22919.00  22900.00  22904.30
# 2025-04-11 15:20:00  NSE:NIFTY1!  22903.15  22915.00  22900.00  22912.00
# 2025-04-11 15:25:00  NSE:NIFTY1!  22911.30  22949.00  22911.00  22945.00
#
#                        volume
# datetime
# 2025-04-09 13:25:00   35325.0
# ...
